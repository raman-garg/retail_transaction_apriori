# %%
#importinf required libraries and the dataset
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
groceries_df = pd.read_csv('groceries_subset.csv', header = None)
groceries_df.head()
# Out:
#     0                 1                    2               3   \
# 0  101      citrus fruit  semi-finished bread       margarine
# 1  102    tropical fruit               yogurt          coffee
# 2  103        whole milk                  NaN             NaN
# 3  104         pip fruit               yogurt   cream cheese
# 4  105  other vegetables           whole milk  condensed milk
#
#                          4    5    6    7    8    9   ...   14   15   16   17  \
# 0               ready soups  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 1                       NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 3              meat spreads  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 4  long life bakery product  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
#
#     18   19   20   21   22   23
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
#checking the shape of dataset
groceries_df.shape
# Out:
# (1000, 24)

# %%
groceries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1000 non-null   int64
#  1   1       1000 non-null   object
#  2   2       784 non-null    object
#  3   3       609 non-null    object
#  4   4       477 non-null    object
#  5   5       370 non-null    object
#  6   6       275 non-null    object
#  7   7       214 non-null    object
#  8   8       160 non-null    object
#  9   9       108 non-null    object
#  10  10      76 non-null     object
#  11  11      54 non-null     object
#  12  12      33 non-null     object
#  13  13      24 non-null     object
#  14  14      18 non-null     object
#  15  15      14 non-null     object
#  16  16      10 non-null     object
#  17  17      7 non-null      object
#  18  18      4 non-null      object
#  19  19      4 non-null      object
#  20  20      3 non-null      object
# ...

# %%
# Creating a list of transactions of items
transactions = []

# Adding all the items from each row in one list leaving 1st column which is just serial number
for i in range(0, 1000):
    transactions.append([str(groceries_df.values[i,u]) for u in range(1, 24)])

# %%
# Calculation Min_support  = 3(3 times a day) * 7 (7 days a week) / 1000 = 0.0021
# Min_confidence = it is set lower to get more relations between products
from apyori import apriori
rules = apriori(transactions, min_support=0.0021, min_confidence=0.20, min_lift=3, min_length = 2)

# %%
# Storing the rules in a result variable
results = list(rules)

# Checking the items that were bought together with the support
results_list = []
for i in range(0, len(results)):
    results_list.append('RULE:' + str(results[i][0]) + 'SUPPORT:' + str(results[i][1]))

# %%
#Printing the result list
print(results_list)
# Out:
# ["RULE:frozenset({'Instant food products', 'hamburger meat'})SUPPORT:0.003", "RULE:frozenset({'root vegetables', 'Instant food products'})SUPPORT:0.003", "RULE:frozenset({'abrasive cleaner', 'berries'})SUPPORT:0.003", "RULE:frozenset({'chicken', 'abrasive cleaner'})SUPPORT:0.003", "RULE:frozenset({'root vegetables', 'abrasive cleaner'})SUPPORT:0.004", "RULE:frozenset({'pork', 'artif. sweetener'})SUPPORT:0.003", "RULE:frozenset({'soda', 'artif. sweetener'})SUPPORT:0.003", "RULE:frozenset({'cream cheese ', 'baking powder'})SUPPORT:0.004", "RULE:frozenset({'baking powder', 'domestic eggs'})SUPPORT:0.005", "RULE:frozenset({'frankfurter', 'baking powder'})SUPPORT:0.005", "RULE:frozenset({'baking powder', 'frozen vegetables'})SUPPORT:0.003", "RULE:frozenset({'margarine', 'baking powder'})SUPPORT:0.003", "RULE:frozenset({'pork', 'baking powder'})SUPPORT:0.003", "RULE:frozenset({'baking powder', 'sugar'})SUPPORT:0.004", "RULE:frozenset({'tropical fruit', 'baking powder'})SUPPORT:0.006", "RUL
# ...
